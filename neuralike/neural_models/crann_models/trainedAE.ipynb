# %%
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
from tensorflow.keras.models import Model
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import Constant, RandomNormal
import seaborn as sns
import matplotlib.pyplot as plt
from astroNN.nn.layers import MCDropout
from scipy.misc import derivative
import scipy.integrate as intg
import scipy as sp

# %%
decoder = tf.keras.models.load_model('../models/decoderJLA.h5')
ffnn = tf.keras.models.load_model('../models/FFNN_JLA2.h5') 
autoencoder = tf.keras.models.load_model('../models/autoencoderJLA.h5')
encoder = tf.keras.models.load_model('../models/encoderJLA.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
ones = np.ones((31,31))
np.shape(ones)
sns.heatmap(pd.DataFrame(ones), 
            fmt='g', xticklabels=False, yticklabels=False, 
            cmap = 'inferno', 
            robust=False)
# Out:
# <AxesSubplot:>

# %%
clean = autoencoder.predict(ones.reshape(1,31*31))
np.shape(clean), np.shape(clean[0,:])
sns.heatmap(pd.DataFrame(clean[0, :].reshape(31,31)), 
            fmt='g', xticklabels=False, yticklabels=False, 
            cmap = 'inferno', 
            robust=False)
# Out:
# <AxesSubplot:>

# %%
clean = autoencoder.predict(clean)
sns.heatmap(pd.DataFrame(clean[0, :].reshape(31,31)), 
            fmt='g', xticklabels=False, yticklabels=False, 
            cmap = 'inferno', 
            robust=False)
# Out:
# <AxesSubplot:>

# %%
clean = autoencoder.predict(clean)
sns.heatmap(pd.DataFrame(clean[0, :].reshape(31,31)), 
            fmt='g', xticklabels=False, yticklabels=False, 
            cmap = 'inferno', 
            robust=False)
# Out:
# <AxesSubplot:>
